# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime
pd.set_option('display.max_columns', 500)

# %%
carac = pd.read_csv("caracteristics.csv", encoding="latin-1")
holi = pd.read_csv("holidays.csv", encoding="latin-1")
places = pd.read_csv("places.csv", encoding="latin-1")
users = pd.read_csv("users.csv", encoding="latin-1")
veh = pd.read_csv("vehicles.csv", encoding="latin-1")

# %% [markdown]
# #### Treating features with some null values and droping useless features

# %%
places = places.drop(["v1", "v2", "voie", "nbv", "pr", "pr1"], axis=1)
places.env1[places.env1 == 99] = 1
places.env1[places.env1 == 3] = 0
for n in places.columns:
    places[n] = places[n].fillna(0)

# %%
# categories between 1 and 14
veh.catv = veh.catv.apply(lambda x: 14 if x > 14 else x)
veh = veh.drop(["senc", "occutc", "obs", "obsm", "choc", "manv"], axis=1)

# %%
carac.an = 2000 + carac.an
carac['date'] = pd.to_datetime([f'{row.an}-{row.mois}-{row.jour}'
                             for _, row in carac.iterrows()] )

carac.atm = carac.atm.fillna(1)
carac.col = carac.col.fillna(6)
carac.com = carac.com.fillna(55)

# %%
carac.drop(['adr', 'gps', 'lat', 'long'], axis=1, inplace=True)

# %%
users['secu'] = users['secu'].fillna(53)
users['secu1']= users['secu'].apply(lambda x: x % 10)
users['locp'] = users['locp'].fillna(0)
users['actp'] = users['actp'].fillna(0)
users['etatp'] = users['etatp'].fillna(0)
users['trajet'] = users['trajet'].fillna(3)
users['an_nais'] = users['an_nais'].fillna(1973)
users = users.drop("place", axis=1)

# %%
df = pd.merge(carac, users, how="outer", on="Num_Acc")
df = pd.merge(df, places, how="outer", on="Num_Acc")
df = pd.merge(df, veh, how="inner", on=["Num_Acc", 'num_veh'])
# filtering for realistic people
df = df[df.an_nais > 1918]

# %%
df['date'] = pd.to_datetime([f'{row.an}-{row.mois}-{row.jour}'
                             for _, row in df.iterrows()] )

# %%
df["age"] = df.an - df.an_nais
df['secu2'] = df['secu'].apply(lambda x: int(x/10) if x>=10 else x)

# Grouping class 2(dead) and 3(Hospitalized) as serious
df['grav1'] = ((df.grav == 2) | (df.grav == 3)).astype(int)

# %%
df.to_csv("df.csv", sep=";")

# %%
sns.set()

# %% [markdown]
# ### Age Analysis

# %%
plt.figure(figsize=(10,15))
for i in range(2):
    print(i)
    ax = plt.subplot(2, 1, i + 1)
    sns.distplot(df[df.grav1 == i].age, bins=20)
    if i:
        plt.title("Serious")
    else:
        plt.title("Not Serious")
plt.show()
# Out:
# 0
# 1

# %%
plt.figure(figsize=(10,7))
sns.distplot(df.age[df.grav==2])

# %% [markdown]
# #### Between serious (S) and not serious (NS) the distribution is almost the same, but for S we can see a higher frequency in age higher than 60's and for those had died it increases, it probably has some influence about the fragile in elder people.

# %% [markdown]
# ###

# %%
df.an_nais.hist(bins=20, figsize=(10,10))

# %% [markdown]
# ## 67% dos acidentes são causados por homens

# %%
plt.hist(df.sexe, bins=3)
# Out:
# (array([1257669.,       0.,  615798.]),
#  array([1.        , 1.33333333, 1.66666667, 2.        ]),
#  <a list of 3 Patch objects>)

# %% [markdown]
# ### não há diferenca entre ser grave e nao grave com o sexo

# %%
# Out:
# 0           2.0
# 1           2.0
# 2           3.0
# 3           3.0
# 4           3.0
# 5           7.0
# 6           7.0
# 7           8.0
# 8           8.0
# 9           8.0
# 10         12.0
# 11         12.0
# 12         12.0
# 13         12.0
# 14         12.0
# 15          5.0
# 16          5.0
# 17          5.0
# 18          5.0
# 19          5.0
# 20          5.0
# 21          9.0
# 22          9.0
# 23         12.0
# 24         12.0
# 25          1.0
# 26          1.0
# 27          1.0
# 28          2.0
# 29          2.0
#            ...
# 1873437    12.0
# 1873438     2.0
# 1873439     2.0
# 1873440     8.0
# 1873441     8.0
# 1873442     2.0
# 1873443     2.0
# 1873444     2.0
# 1873445     2.0
# 1873446     2.0
# 1873447     3.0
# 1873448     3.0
# 1873449     3.0
# 1873450     3.0
# 1873451     3.0
# 1873452     5.0
# 1873453     5.0
# 1873454     5.0
# 1873455     5.0
# 1873456     5.0
# 1873457     6.0
# 1873458     6.0
# 1873459     6.0
# 1873460     6.0
# 1873461     7.0
# 1873462     7.0
# 1873463     7.0
# 1873464     7.0
# 1873465    12.0
# 1873466    12.0
# Name: mois, Length: 1873467, dtype: float64

# %%
plt.figure(figsize=(20,15))
sns.distplot(df.mois.dropna(), bins=10, kde=False)
plt.title("Numero de acidentes x Mês")
plt.savefig("Numero de acidentes x Mês.jpg")

# %% [markdown]
# ### Vemos que o numero de acidentes é maior no inverno, por que?

# %%
sns.distplot(df.surf.dropna(), bins=10, kde=False)

# %%
df.catv.hist(bins=50, figsize=(15,10))

# %%
plt.figure(figsize=(15,20))
for i in range(12):
    plt.subplot(12,1, i+1)
    sns.distplot(df[df.mois == i + 1].atm,kde=False)
plt.tight_layout()
plt.show()

# %%
nao_grave = df[(df.grav1==0)].secu1.value_counts()/df[(df.grav1==0)].secu1.count()

# %%
grave = df[(df.grav1==1)].secu1.value_counts()/df[(df.grav1==1)].secu1.count()

# %%
grave/nao_grave
# Out:
# 0.0    2.238224
# 1.0    0.887578
# 2.0    3.305970
# 3.0    1.006532
# Name: secu1, dtype: float64

# %% [markdown]
# ### Pessoas que nao usam cinto tem 3.3x mais chances de se envolverem em um acidente grave

# %%
import numpy as np
z = df["agg"].value_counts()/10000
plt.scatter(df["agg"].value_counts()/10000, [1,1],s=z*50)
plt.xlim((40,150))
plt.show()

# %%
df.head()
# Out:
#         Num_Acc      an  mois  jour    hrmn  lum  agg  int  atm  col  com  \
# 0  2.016000e+11  2016.0   2.0   1.0  1445.0  1.0  2.0  1.0  8.0  3.0  5.0
# 1  2.016000e+11  2016.0   2.0   1.0  1445.0  1.0  2.0  1.0  8.0  3.0  5.0
# 2  2.016000e+11  2016.0   3.0  16.0  1800.0  1.0  2.0  6.0  1.0  6.0  5.0
# 3  2.016000e+11  2016.0   3.0  16.0  1800.0  1.0  2.0  6.0  1.0  6.0  5.0
# 4  2.016000e+11  2016.0   3.0  16.0  1800.0  1.0  2.0  6.0  1.0  6.0  5.0
#
#      dep       date  catu  grav  sexe  trajet  secu  locp  actp  etatp  \
# 0  590.0 2016-02-01   1.0   1.0   2.0     0.0  11.0   0.0   0.0    0.0
# 1  590.0 2016-02-01   1.0   3.0   1.0     9.0  21.0   0.0   0.0    0.0
# 2  590.0 2016-03-16   1.0   3.0   1.0     5.0  11.0   0.0   0.0    0.0
# 3  590.0 2016-03-16   2.0   3.0   1.0     0.0  11.0   0.0   0.0    0.0
# 4  590.0 2016-03-16   2.0   3.0   2.0     0.0  11.0   0.0   0.0    0.0
#
#    an_nais num_veh  secu1  catr  circ  vosp  prof  plan  lartpc  larrout  \
# 0   1983.0     B02    1.0   3.0   2.0   0.0   1.0   3.0     0.0      0.0
# 1   2001.0     A01    1.0   3.0   2.0   0.0   1.0   3.0     0.0      0.0
# 2   1960.0     A01    1.0   3.0   1.0   0.0   1.0   2.0     0.0     58.0
# 3   2000.0     A01    1.0   3.0   1.0   0.0   1.0   2.0     0.0     58.0
# 4   1962.0     A01    1.0   3.0   1.0   0.0   1.0   2.0     0.0     58.0
#
#    surf  infra  situ  env1  catv  idade  secu2  grav1  dep2   Ain   AIN   ain  \
# 0   1.0    0.0   1.0   0.0   7.0   33.0    1.0    0.0  59.0  Nord  NORD  nord
# 1   1.0    0.0   1.0   0.0   2.0   15.0    2.0    1.0  59.0  Nord  NORD  nord
# 2   1.0    0.0   1.0   0.0   7.0   56.0    1.0    1.0  59.0  Nord  NORD  nord
# 3   1.0    0.0   1.0   0.0   7.0   16.0    1.0    1.0  59.0  Nord  NORD  nord
# 4   1.0    0.0   1.0   0.0   7.0   54.0    1.0    1.0  59.0  Nord  NORD  nord
#
#    A500
# 0  N630
# 1  N630
# 2  N630
# 3  N630
# 4  N630

# %%
n_pessoas = df[(df.grav1 == 1) & (df.an>=2010) & (df.an<=2013)].groupby(["Num_Acc"])['Num_Acc'].count()

n_pessoas = pd.DataFrame(n_pessoas)

n_pessoas.columns = ["n"]

n_pessoas = n_pessoas.reset_index()

n_pessoas_grave = n_pessoas.groupby("n").count()

n_pessoas1 = df[(df.grav1 == 0) & (df.an>=2010) & (df.an<=2013)].groupby(["Num_Acc"])['Num_Acc'].count()

n_pessoas1 = pd.DataFrame(n_pessoas1)

n_pessoas1.columns = ["n"]

n_pessoas1 = n_pessoas1.reset_index()

n_pessoas_nao_grave = n_pessoas1.groupby("n").count()

# %%
p_grave=(n_pessoas_grave.sort_values(by="Num_Acc", ascending=False).head(3)/n_pessoas_grave.sum() *100)#.T.plot(kind='bar', stacked=True)
p_grave.columns = ["n"]
p_nao_grave = (n_pessoas_nao_grave.sort_values(by="Num_Acc", ascending=False).head(3)/n_pessoas_nao_grave.sum()*100)
p_nao_grave.columns = ["n"]

# %%
print(p_grave, p_nao_grave)
# Out:
#            n
# n
# 1  85.934707
# 2  10.576732
# 3   2.298622            n
# n
# 2  45.061628
# 1  37.001842
# 3  11.687546

# %%
n_pessoas = df[df.grav1 == 1].groupby(["Num_Acc"])['Num_Acc'].count()

n_pessoas = pd.DataFrame(n_pessoas)

n_pessoas.columns = ["n"]

n_pessoas = n_pessoas.reset_index()

n_pessoas_grave = n_pessoas.groupby("n").count()

# %%
p_grave=(n_pessoas_grave.sort_values(by="Num_Acc", ascending=False).head(3)/n_pessoas_grave.sum() *100)#.T.plot(kind='bar', stacked=True)
p_grave.columns = ["n"]

# %%
n_pessoas1 = df[df.grav1 == 0].groupby(["Num_Acc"])['Num_Acc'].count()

n_pessoas1 = pd.DataFrame(n_pessoas1)

n_pessoas1.columns = ["n"]

n_pessoas1 = n_pessoas1.reset_index()

n_pessoas_nao_grave = n_pessoas1.groupby("n").count()

# %%
p_nao_grave = (n_pessoas_nao_grave.sort_values(by="Num_Acc", ascending=False).head(3)/n_pessoas_nao_grave.sum()*100)
p_nao_grave.columns = ["n"]

# %%
print(p_grave, p_nao_grave)
# Out:
#            n
# n
# 1  85.934707
# 2  10.576732
# 3   2.298622                n
# n
# 2  276962.162162
# 1  227424.324324
# 3   71835.135135

# %%
plt.figure(figsize=(20,15))
p_nao_grave.sort_index().T.plot(kind='bar', stacked=True)
plt.xticks(rotation=0)
plt.title("N pessoas no veículo - Acidentes não Graves ")
plt.savefig("N pessoas no veículo - Acidentes não Graves.jpg")

# %%
plt.figure(figsize=(20,10))
p_grave.T.plot(kind='bar', stacked=True)
plt.xticks(rotation=0)
plt.title("N pessoas no veículo - Acidentes Graves ")
plt.savefig("N pessoas no veículo - Acidentes Graves.jpg")

# %%
x_col= ['secu1','secu','col','catr','agg','plan','catu','situ','dep','atm','grav1','grav']

# %%
from string import ascii_letters
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(40,30))


sns.set(style="white")

# Compute the correlation matrix
corr = df[x_col].corr()

# Generate a mask for the upper triangle
mask = np.zeros_like(corr, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(220, 10, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask, cmap=cmap, vmax=.3, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})

plt.savefig("heatmap.jpg")

# %%
dep = pd.read_csv("departement.csv")

# %%
df["dep2"] = df.dep/10

# %%
dep.head()
# Out:
#    1  01                      Ain                      AIN  \
# 0  2  02                    Aisne                    AISNE
# 1  3  03                   Allier                   ALLIER
# 2  5  05             Hautes-Alpes             HAUTES-ALPES
# 3  4  04  Alpes-de-Haute-Provence  ALPES-DE-HAUTE-PROVENCE
# 4  6  06          Alpes-Maritimes          ALPES-MARITIMES
#
#                        ain        A500
# 0                    aisne        A250
# 1                   allier        A460
# 2             hautes-alpes      H32412
# 3  alpes-de-haute-provence  A412316152
# 4          alpes-maritimes   A41256352

# %%
dep.columns = ['1', 'dep2', 'Ain', 'AIN', 'ain', 'A500']
dep = dep[['dep2', 'Ain', 'AIN', 'ain', 'A500']]

# %%
dep = dep[dep.dep2 != "2a"]

# %%
dep.dep2 = dep.dep2.astype(int)

# %%
df = pd.merge(df, dep, how="outer" , on="dep2")

# %%
df.columns
# Out:
# Index(['Num_Acc', 'an', 'mois', 'jour', 'hrmn', 'lum', 'agg', 'int', 'atm',
#        'col', 'com', 'dep', 'date', 'catu', 'grav', 'sexe', 'trajet', 'secu',
# 2015-07-31  11840  11840  11840  11337  11337  11337  11337
# 2015-08-31  10149  10149  10149   9632   9632   9632   9632
# 2015-09-30  11824  11824  11824  11315  11315  11315  11315
# 2015-10-31  11749  11749  11749  11178  11178  11178  11178
# 2015-11-30  11224  11224  11224  10741  10741  10741  10741
# 2015-12-31  11150  11150  11150  10602  10602  10602  10602
# 2016-01-31  10704  10704  10704  10248  10248  10248  10248
# 2016-02-29   9026   9026   9026   8584   8584   8584   8584
# 2016-03-31  10242  10242  10242   9684   9684   9684   9684
# 2016-04-30   9980   9980   9980   9515   9515   9515   9515
# 2016-05-31  11356  11356  11356  10771  10771  10771  10771
# 2016-06-30  12038  12038  12038  11467  11467  11467  11467
# 2016-07-31  12083  12083  12083  11481  11481  11481  11481
# 2016-08-31   9999   9999   9999   9431   9431   9431   9431
# 2016-09-30  11979  11979  11979  11432  11432  11432  11432
# 2016-10-31  12489  12489  12489  11986  11986  11986  11986
# 2016-11-30  11989  11989  11989  11479  11479  11479  11479
# 2016-12-31  11525  11525  11525  10899  10899  10899  10899
#
# [144 rows x 43 columns]

# %%
n=0
(df[df.grav1 == n].ain.value_counts().head(5)/df[df.grav1 == n].Num_Acc.nunique() *100).plot(kind="barh")

# %% [markdown]
# ##

# %%
n=0
df[df['agg']==n].grav1.value_counts()/df[df['agg']==n].grav1.count()*100
# Out:
# Series([], Name: grav1, dtype: float64)

# %%
n=1
df[df.grav1 == n]['agg'].value_counts()/df[df.grav1 == n]['agg'].count() *100
# Out:
# 1.0    50.209756
# 2.0    49.790244
# Name: agg, dtype: float64

# %%
n=1
df[df.grav1 == n]['agg'].value_counts()/df[df.grav1 == n]['agg'].count() *100

# %%
n = 1
grave = (df[df.grav1 == n].plan.value_counts()/df.plan.value_counts()*100)

n = 0
n_grave = (df[df.grav1 == n].plan.value_counts()/df.plan.value_counts()*100)
 
grave/n_grave
# Out:
# 0.0    0.266817
# 1.0    0.271116
# 2.0    0.549593
# 3.0    0.566480
# 4.0    0.616744
# Name: plan, dtype: float64

# %%
grave
# Out:
# 1.0    21.328953
# 2.0    35.466909
# 3.0    36.162616
# 0.0    21.061992
# 4.0    38.147279
# Name: plan, dtype: float64

# %%
grave
# Out:
# 1.0    16.507363
# 2.0     2.671357
# 3.0     2.600473
# 0.0     1.396929
# 4.0     0.476977
# Name: plan, dtype: float64

# %%
n_grave
# Out:
# 1.0    79.750184
# 0.0     6.857559
# 2.0     6.366485
# 3.0     6.012791
# 4.0     1.012980
# Name: plan, dtype: float64

# %%
df[df.grav1==1].an.value_counts().sort_index().plot()

# %%
df.Num_Acc

# %%
df[df.an == 2016].Num_Acc.nunique()
# Out:
# 59430

# %% [markdown]
# x_col= ['col','catr','agg','plan','catu','situ','dep','atm']
# df_dummies = pd.DataFrame()
# for coluna in x_col:
#     temp = pd.get_dummies(df[coluna], prefix=coluna)
#     df_dummies = pd.concat([df_dummies, temp], axis=1)
#
# df_dummies.head()
